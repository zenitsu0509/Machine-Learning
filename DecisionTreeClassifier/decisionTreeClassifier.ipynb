# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal length (cm)'].plot(kind='hist', bins=20, title='sepal length (cm)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sepal width (cm)'].plot(kind='hist', bins=20, title='sepal width (cm)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
df.isnull().any()
# Out:
# sepal length (cm)    False
# sepal width (cm)     False
# petal length (cm)    False
# petal width (cm)     False
# dtype: bool

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt
df['sepal length (cm)'].plot(kind='line', figsize=(8, 4), title='sepal length (cm)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
sns.lineplot(data=df, x='sepal length (cm)', y='sepal width (cm)')
plt.show()

# %%
sns.lineplot(data = df,x ='petal length (cm)',y = 'petal length (cm)')
plt.show()

# %%
X = iris.data
y = iris.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 47,test_size = 0.25)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion = 'entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred  = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy Score on train data: ', accuracy_score(y_true=y_train, y_pred=clf.predict(X_train)))
print('Accuracy Score on test data: ', accuracy_score(y_true=y_test, y_pred=y_pred))
# Out:
# Accuracy Score on train data:  1.0
# Accuracy Score on test data:  0.9736842105263158

# %%
clf = DecisionTreeClassifier(criterion = 'entropy',min_samples_split = 50)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=70)

# %%
print("accuracy on train data:",accuracy_score(y_true= y_train,y_pred = clf.predict(X_train)))
print("accuaracy on test data:",accuracy_score(y_true = y_test,y_pred = clf.predict(X_test)))
# Out:
# accuracy on train data: 0.9553571428571429
# accuaracy on test data: 0.9736842105263158
